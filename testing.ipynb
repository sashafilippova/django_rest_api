# %%
# imports 

from util import Eviction_Scraper, normalize_data, initiate_driver
import pandas as pd
import numpy as np
import psycopg2.extras

from server import initiate_db
from db import DB

# initiate conn with database
conn = initiate_db()

# initiate an instance of the DB class
db = DB(conn)

# %% [markdown]
# 1. Test creating tables in db. Quering a newly created table must return no results:

# %%
db.create_schema()
db.query_all_records('eviction_records')
# Out:
# []

# %% [markdown]
# 2. Test injecting new records:

# %%
data = pd.read_csv('evictions_2019-2022_colnames_modified.csv')
db.inject_data(data, 'eviction_records')
db.query_all_records('eviction_records')
# Out:
# converted pd into records
# finished commit
# [{'case_id': '19CV00674',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CHERYL HOFF VS. CLEON LEWIS ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 7),
#   'case_type': 'G2-EVICTION',
#   'amount': 1800,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 5, 14),
#   'plaintiff_name': 'CHERYL HOFF',
#   'plaintiff_address': '1505 N PARK AVE CINCINNATI OH 45215',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'CLEON LEWIS',
#   'defendant_address': '1323 WOODLAND AVE CINCINNATI OH 45237',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00673',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'BERT YOUKEY TRUST VS. MICHAEL STURGEON ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 7),
#   'case_type': 'G2-EVICTION',
#   'amount': 2150,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 7, 15),
#   'plaintiff_name': 'BERT YOUKEY TRUST',
#   'plaintiff_address': '4350 REGENCY RIDGE CT CINCINNATI OH 45248',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'MICHAEL STURGEON',
#   'defendant_address': '% CARDINAL MOTORS 4805 DIXIE HWYFAIRFIELD OH 45014',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00515',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'WILLIAM H CHAPEL SR VS. LARELLE N BRUCE',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 4),
#   'case_type': 'G2-EVICTION',
#   'amount': 1300,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 3, 12),
#   'plaintiff_name': 'WILLIAM H CHAPEL SR',
#   'plaintiff_address': '2322 ROHS ST CINCINNATI OH 45219',
#   'plaintiff_attorney': None,
#   'defendant_name': 'LARELLE N BRUCE',
#   'defendant_address': 'APT 1 5824 SHADYMIST LANECINCINNATI OH 45239',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00371',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ANNA MARTIN VS. SANDI HICKS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 3),
#   'case_type': 'G2-EVICTION',
#   'amount': 295,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 4, 26),
#   'plaintiff_name': 'ANNA MARTIN',
#   'plaintiff_address': '1817 CREST HILL AVE #2 CINCINNATI OH 45237',
#   'plaintiff_attorney': None,
#   'defendant_name': 'SANDI HICKS',
#   'defendant_address': '2805 WERK RD APT 15 CINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00235',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'JOSEPH J JACKSON VS. LANITA DYKES',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 3),
#   'case_type': 'G2-EVICTION',
#   'amount': 1500,
#   'disposition': 'JUDGMENT FOR DEFENDANT',
#   'disposition_date': datetime.date(2019, 3, 29),
#   'plaintiff_name': 'JOSEPH J JACKSON',
#   'plaintiff_address': 'STE 16 800 COMPTON RDCINCINNATI OH 45231',
#   'plaintiff_attorney': 'GILBERT/SCOTT/T',
#   'defendant_name': 'LANITA DYKES',
#   'defendant_address': '218 RIDGEWAY RD CINCINNATI OH 45216',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00234',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'JOSEPH J JACKSON VS. SHAWNITA EDWARDS ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 3),
#   'case_type': 'G2-EVICTION',
#   'amount': 1500,
#   'disposition': 'JUDGMENT FOR DEFENDANT',
#   'disposition_date': datetime.date(2019, 3, 29),
#   'plaintiff_name': 'JOSEPH J JACKSON',
#   'plaintiff_address': 'STE 16 800 COMPTON RDCINCINNATI OH 45231',
#   'plaintiff_attorney': 'GILBERT/SCOTT/T',
#   'defendant_name': 'SHAWNITA EDWARDS',
#   'defendant_address': 'AKA SHAUNITA 5532 DUNNING PLACECINCINNATI OH 45227',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00200',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'PHYLLIS BABER VS. LINDA LESTER',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 2),
#   'case_type': 'G2-EVICTION',
#   'amount': 2788,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 3, 8),
#   'plaintiff_name': 'PHYLLIS BABER',
#   'plaintiff_address': '867 ADAMS ST CINCINNATI OH 45215',
#   'plaintiff_attorney': None,
#   'defendant_name': 'LINDA LESTER',
#   'defendant_address': '620 JACKSON ST APT 2 CINCINNATI OH 45215',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00198',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'DANIEL KEITH COOK VS. CHARLES JEFF HUNTER',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 2),
#   'case_type': 'G2-EVICTION',
#   'amount': 8500,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 2, 27),
#   'plaintiff_name': 'DANIEL KEITH COOK',
#   'plaintiff_address': '5009 LORD ALFRED CT SHARONVILLE OH 45241',
#   'plaintiff_attorney': None,
#   'defendant_name': 'CHARLES JEFF HUNTER',
#   'defendant_address': '5009 LORD ALFRED CT (FRONT RIGHT ROOM)SHARONVILLE OH 45241',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00193',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ST 4 ENDEAVORS LLC VS. THEODORE JENKINS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 2),
#   'case_type': 'G2-EVICTION',
#   'amount': 8556,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 1, 30),
#   'plaintiff_name': 'ST 4 ENDEAVORS LLC',
#   'plaintiff_address': 'PO BOX 15715 CINCINNATI OH 45215',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'THEODORE JENKINS',
#   'defendant_address': 'APT #22 2759 POWELL AVECINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00133',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'INDIAN WALK APARTMENTS INC VS. ANDREW WILLIAMS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 2),
#   'case_type': 'G2-EVICTION',
#   'amount': 475,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 5, 3),
#   'plaintiff_name': 'INDIAN WALK APARTMENTS INC',
#   'plaintiff_address': '5438 PALISADES DR CINCINNATI OH 45238',
#   'plaintiff_attorney': 'STAGNARO JR/EUGENE/J',
#   'defendant_name': 'ANDREW WILLIAMS',
#   'defendant_address': 'APT 5 6437 GRACELY DRCINCINNATI OH 45233',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01521',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ES2 LLC VS. CHAMPAGNE CHRISTIAN ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 16),
#   'case_type': 'G2-EVICTION',
#   'amount': 6948,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 4),
#   'plaintiff_name': 'ES2 LLC',
#   'plaintiff_address': '310 OAK STREET CINCINNATI OH 45219',
#   'plaintiff_attorney': 'BREWER/KEVIN/R',
#   'defendant_name': 'CHAMPAGNE CHRISTIAN',
#   'defendant_address': '506 RIDDLE ROAD APT #25 CINCINNATI OH 45220',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01516',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'PARKVIEW COMMUNITIES LLC VS. DOUGLAS M ROBINSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 16),
#   'case_type': 'G2-EVICTION',
#   'amount': 710,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 2, 25),
#   'plaintiff_name': 'PARKVIEW COMMUNITIES LLC',
#   'plaintiff_address': 'PO BOX 30277 CINCINNATI OH 45230',
#   'plaintiff_attorney': 'DONNETT/DAVID/D',
#   'defendant_name': 'DOUGLAS M ROBINSON',
#   'defendant_address': '#2 3001 WESTWOOD NORTHERN BLVDCINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01510',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'RICHARD HOUSE VS. ASISHA MILLS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 16),
#   'case_type': 'G2-EVICTION',
#   'amount': 750,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 3, 19),
#   'plaintiff_name': 'RICHARD HOUSE',
#   'plaintiff_address': '4527 HECTOR AVE CINCINNATI OH 45227',
#   'plaintiff_attorney': 'BREWER/KEVIN/R',
#   'defendant_name': 'ASISHA MILLS',
#   'defendant_address': '3453 HALLWOOD PLACE #2 CINCINNATI OH 45229',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01207',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. WAYNE STENSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 648,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'WAYNE A STENSON',
#   'defendant_address': 'STE 524 3951 W 8TH STCINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01206',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. DAVID SKEENS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 203,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'DAVID L SKEENS',
#   'defendant_address': '3128 BLUEACRES DR CINCINNATI OH 45239',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01205',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. JAMES SCHWARTZ',
#   'judge': 'WILLIAM L MALLORY',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 796,
#   'disposition': 'REFERRED TO MAGISTRATE',
#   'disposition_date': datetime.date(2022, 3, 23),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'JAMES J SCHWARTZ',
#   'defendant_address': 'STE 511 3951 W 8TH STCINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01204',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CINCINNATI METRO HSNG AUTHORTY VS. SHAWN P RUSSELL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 400,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HSNG AUTHORTY',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'SHAWN P RUSSELL',
#   'defendant_address': '3951 W 8TH ST SUITE 715 CINCINNATI OH 452052159',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01199',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. MOVITA GRAHAM',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 306,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'MONVITA GRAHAM',
#   'defendant_address': 'STE 623 3951 W 8TH STCINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01198',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. WAKI GOLDSMITH',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 1194,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'WAKI GOLDSMITH',
#   'defendant_address': 'STE 509 3951 W 8TH STCINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01197',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': "CMHA VS. RE'TISA CHANEY",
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 1716,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'RETISA N CHANEY',
#   'defendant_address': 'STE 405 3951 W 8TH STCINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01196',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. MAURICE BROWN',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 2456,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'HEIS/FOREST/S',
#   'defendant_name': 'MAURICE A BROWN',
#   'defendant_address': '% CM TEMPORARY SERVICES 270 NORTHLAND BOULEVARD #125CINCINNATI OH 45246',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01195',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. CLIFTON NELSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 303,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'CLIFTON L NELSON',
#   'defendant_address': '1621 LINN ST SUITE 410 CINCINNATI OH 452142549',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01194',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. KELSEY PRICE',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 234,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'KELSEY M PRICE',
#   'defendant_address': '835 POPLAR ST SUITE 911 CINCINNATI OH 452142538',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01193',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. TYRONNA ADAMS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 100,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'TYRONNA J ADAMS',
#   'defendant_address': '835 POPLAR ST SUITE 711 CINCINNATI OH 452142536',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01191',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. REGINA IRBY',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 696,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'REGINA L IRBY',
#   'defendant_address': '3951 W 8TH ST SUITE 608 CINCINNATI OH 452052158',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01190',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. ASHLEIGH GRIFFIN',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 415,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'ASHLEIGH M GRIFFIN',
#   'defendant_address': '569 W LIBERTY ST SUITE 102 CINCINNATI OH 452142628',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01188',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. THOMASA BUCK',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 719,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'THOMASA S BUCK',
#   'defendant_address': '1621 LINN ST SUITE 501 CINCINNATI OH 452142550',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01186',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. SHAILA KNIGHT',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 195,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'SHAILA E KNIGHT',
#   'defendant_address': '835 POPLAR ST SUITE 205 CINCINNATI OH 452142531',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01185',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. MAKAILA LUCKEY',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 393,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'MAKAILA A LUCKEY',
#   'defendant_address': '835 POPLAR ST SUITE 204 CINCINNATI OH 452142531',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01184',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. BRADEN TURNER',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 275,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'BRADEN R TURNER',
#   'defendant_address': '1621 LINN ST SUITE 407 CINCINNATI OH 452142549',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01175',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. DONNA HENDERSON AND TOMMY HENDERSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 908,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 1, 3),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'DONNA L HENDERSON',
#   'defendant_address': '10121 SHIVERS CT SUITE 3105 CINCINNATI OH 452151729',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01174',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. LYN WILLIAMS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 428,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'LYN R WILLIAMS',
#   'defendant_address': '1820 RUTLAND AVE SUITE 101 CINCINNATI OH 452071244',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01173',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. BONNIE ROGESKI',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 607,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'BONNIE E ROGESKI',
#   'defendant_address': '1820 RUTLAND AVE SUITE 106 CINCINNATI OH 452071244',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01172',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. WALTER ROGERS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 699,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'WALTER E ROGERS',
#   'defendant_address': '330 FOREST AVE SUITE 1303 CINCINNATI OH 452292462',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01166',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. JAMIL GIVENS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 825,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'JAMIL D GIVENS',
#   'defendant_address': '5432 HOLLAND DR SUITE 1040 CINCINNATI OH 452321220',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01164',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. M THOMPSON VENUS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 448,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 2, 19),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'VENUS/M/THOMPSON',
#   'defendant_address': '784 GREENWOOD AVE SUITE 416 CINCINNATI OH 452291860',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01143',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CENTURY LAKES LLC VS. BRITTANY NICHOLSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 1231,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 4, 9),
#   'plaintiff_name': 'CENTURY LAKES LLC',
#   'plaintiff_address': '51 BISHOPSGATE DR CINCINNATI OH 45246',
#   'plaintiff_attorney': 'DONNETT/DAVID/D',
#   'defendant_name': 'BRITTANY NICHOLSON',
#   'defendant_address': '73 BISHOPSGATE DR #307 CINCINNATI OH 45246',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01142',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'HILLCREST MANAGEMENT VS. QUENTIN DIXON ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 5000,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 3, 28),
#   'plaintiff_name': 'HILLCREST MANAGEMENT',
#   'plaintiff_address': 'CYPRESS VIEW LLC PO BOX 9316CINCINNATI OH 45209',
#   'plaintiff_attorney': 'DONNETT/DAVID/D',
#   'defendant_name': 'QUENTIN DIXON',
#   'defendant_address': '6518 TUNE AVE #3 CINCINNATI OH 45213',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01135',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'MT WASHINGTON POINTE VS. MARCELLA BENNETT',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 10000,
#   'disposition': 'REFERRED TO MAGISTRATE',
#   'disposition_date': datetime.date(2020, 2, 12),
#   'plaintiff_name': 'MT WASHINGTON POINTE',
#   'plaintiff_address': '% BALANCED PROP SOLUTIONS AGNT 11353 REED HARTMAN HWY STE 400CINCINNATI OH 45241',
#   'plaintiff_attorney': None,
#   'defendant_name': 'MARCELLA BENNETT',
#   'defendant_address': '1829 SUTTON AVE #3 CINCINNATI OH 45230',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01120',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ENTRUST ADMINISTRATION INC VS. RUTH STEVENSON',
#   'judge': 'WILLIAM L MALLORY',
#   'filed_date': datetime.date(2019, 1, 11),
#   'case_type': 'G2-EVICTION',
#   'amount': 2750,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2020, 2, 4),
#   'plaintiff_name': 'ENTRUST ADMINISTRATION INC',
#   'plaintiff_address': '555 12TH ST OAKLAND CA 94607',
#   'plaintiff_attorney': 'WHITFIELD/JAMES/J',
#   'defendant_name': 'RUTH STEVENSON',
#   'defendant_address': '1158 TOWNE ST APT 2 CINCINNATI OH 45216',
#   'defendant_attorney': 'PURTELL/BILL/L',
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01009',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'REINVEST CONSULTANTS LLC VS. CAROLYN R CRAWFORD',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 10),
#   'case_type': 'G2-EVICTION',
#   'amount': 2780,
#   'disposition': None,
#   'disposition_date': None,
#   'plaintiff_name': 'REINVEST CONSULTANTS LLC',
#   'plaintiff_address': '1894 E GALBRAITH ROAD CINCINNATI OH 45215',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'CAROLYN R CRAWFORD',
#   'defendant_address': '7126 HIRSCH CINCINNATI OH 45237',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00907',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ANDREW STETSON VS. STACEY GREEN',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 10),
#   'case_type': 'G2-EVICTION',
#   'amount': 4100,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 3, 15),
#   'plaintiff_name': 'ANDREW STETSON',
#   'plaintiff_address': '% TERRENCE D BAZELEY 13 E COURT ST STE 200CINCINNATI OH 45202',
#   'plaintiff_attorney': 'BAZELEY/TERRENCE/D',
#   'defendant_name': 'STACEY GREEN',
#   'defendant_address': 'APT 1 1804 W NORTH BEND RDCINCINNATI OH 45242',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00906',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'MARK GILLESPIE VS. MICHELE RICKER',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 10),
#   'case_type': 'G2-EVICTION',
#   'amount': 620,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 3, 12),
#   'plaintiff_name': 'MARK GILLESPIE',
#   'plaintiff_address': 'PO BOX 30253 CINCINNATI OH 45230',
#   'plaintiff_attorney': None,
#   'defendant_name': 'MICHELE RICKER',
#   'defendant_address': '1958 SUTTON AVE APT 2 CINCINNATI OH 45230',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00894',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FOXWOOD LLC VS. WILLIAM TOOTHACKER',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 10),
#   'case_type': 'G2-EVICTION',
#   'amount': 4915,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 6, 12),
#   'plaintiff_name': 'FOXWOOD LLC',
#   'plaintiff_address': 'AKA FOXWOOD APARTMENTS 3338 ALAMO AVENUECINCINNATI OH 45209',
#   'plaintiff_attorney': 'BREWER/KEVIN/R',
#   'defendant_name': 'WILLIAM TOOTHACKER',
#   'defendant_address': '6773 RAYBEAR DR CANAL WINCHESTER OH 43110',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00893',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ANTHONY W WILLIAMS VS. GLADYS SMITH',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 10),
#   'case_type': 'G2-EVICTION',
#   'amount': 1590,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 7, 8),
#   'plaintiff_name': 'ANTHONY W WILLIAMS',
#   'plaintiff_address': '4306 FLORAL AVE CINCINNATI OH 45212',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'GLADYS SMITH',
#   'defendant_address': '242 MCCORMICK PL APT 2 CINCINNATI OH 45219',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00798',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CAMAPLAN VS. BRADLEY A FERTIG',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 9),
#   'case_type': 'G2-EVICTION',
#   'amount': 2340,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 4, 1),
#   'plaintiff_name': 'CAMAPLAN',
#   'plaintiff_address': 'FBO JOSEPH W DAVIDSON IRA 4607 PERRY STREETCINCINNATI OH 45242',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'BRADLEY A FERTIG',
#   'defendant_address': 'AKA BRAD FERTIG 7200 OSCEOLA DRCINCINNATI OH 45243',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00797',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'BEECH HILL APARTMENTS LLC VS. ALONA M BARNES',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 9),
#   'case_type': 'G2-EVICTION',
#   'amount': 317,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 6, 4),
#   'plaintiff_name': 'BEECH HILL APARTMENTS LLC',
#   'plaintiff_address': '%SUNDANCE PROPERTY MGMT LLC 9918 CARVER ROAD SUITE 110CINCINNATI OH 45242',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'ALONA M BARNES',
#   'defendant_address': '5653 BEECHMONT AVE APT 3 CINCINNATI OH 45230',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV00796',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'TLG PARTNERS LLC VS. REGINA RICHARDSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 9),
#   'case_type': 'G2-EVICTION',
#   'amount': 1525,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 6, 4),
#   'plaintiff_name': 'TLG PARTNERS LLC',
#   'plaintiff_address': 'SIIT SEPTEM INVESTMENTS INC 9918 CARVER ROAD SUITE 110CINCINNATI OH 45242',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'REGINA RICHARDSON',
#   'defendant_address': '2662 MONTANA AVE APT 64 CINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV02664',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'GRISTMILL PROPERTIES LLC VS. AQUANETTE MORTON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 24),
#   'case_type': 'G2-EVICTION',
#   'amount': None,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 4, 15),
#   'plaintiff_name': 'GRISTMILL PROPERTIES LLC',
#   'plaintiff_address': 'PO BOX 756 MILFORD OH 45150',
#   'plaintiff_attorney': 'MEZHER/KATHLEEN/D',
#   'defendant_name': 'AQUANETTE MORTON',
#   'defendant_address': '10555 MONTGOMERY RD #43 CINCINNATI OH 45242',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV02416',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'LISA EVERINGHA VS. MICHAEL S WILSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 22),
#   'case_type': 'G2-EVICTION',
#   'amount': 685,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 9, 19),
#   'plaintiff_name': 'LISA EVERINGHA',
#   'plaintiff_address': 'BACK OFFICE 5928 BELMONT AVECINCINNATI OH 45224',
#   'plaintiff_attorney': None,
#   'defendant_name': 'MICHAEL S WILSON',
#   'defendant_address': 'APT D1 2025 W GALBRAITHCINCINNATI OH 45239',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV02123',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FATH PROPERTIES VS. DANYALLE BRYANT',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 18),
#   'case_type': 'G2-EVICTION',
#   'amount': 743,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 5, 17),
#   'plaintiff_name': 'FATH PROPERTIES',
#   'plaintiff_address': 'LISA RIDGE APARTMENTS 255 EAST FIFTH ST SUITE 2300CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'DANYALLE BRYANT',
#   'defendant_address': '2482 QUEEN CITY AVENUE #11 CINCINNATI OH 45238',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01779',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'JOSEPH MICHELS VS. JOE WIRA ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 17),
#   'case_type': 'G2-EVICTION',
#   'amount': 1800,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 3, 5),
#   'plaintiff_name': 'JOSEPH MICHELS',
#   'plaintiff_address': '1676 LEONA DR CINCINNATI OH 45238',
#   'plaintiff_attorney': None,
#   'defendant_name': 'JOE WIRA',
#   'defendant_address': '1717 ILIFF AVE CINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01664',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FATH PROPERTIES VS. LOREN LAW',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 17),
#   'case_type': 'G2-EVICTION',
#   'amount': 975,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 1, 8),
#   'plaintiff_name': 'FATH PROPERTIES',
#   'plaintiff_address': 'LAKE OF THE WOODS 255 EAST FIFTH ST STE 2300CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'LOREN LAW',
#   'defendant_address': '2703 COY STREET #7 CINCINNATI OH 45219',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01631',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'NORTHGATE MEADOWS APTS LLC VS. JASMINE HARTZELL ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 17),
#   'case_type': 'G2-EVICTION',
#   'amount': 6830,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 6, 17),
#   'plaintiff_name': 'NORTHGATE MEADOWS APTS LLC',
#   'plaintiff_address': '% PLK COMMUNITIES LLC 10101 ARBORWOOD DRCINCINNATI OH 45251',
#   'plaintiff_attorney': 'GREENBERGER/JEFFREY/J',
#   'defendant_name': 'JASMINE HARTZELL',
#   'defendant_address': '10152 ARBORWOOD DR #505 CINCINNATI OH 45251',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV01626',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'BRIXWORTH LLC VS. LAKEISHA RODGERS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 17),
#   'case_type': 'G2-EVICTION',
#   'amount': 5650,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 3, 26),
#   'plaintiff_name': 'BRIXWORTH LLC',
#   'plaintiff_address': '% PLK COMMUNITIES LLC 5701 SPRINGDALE RDCINCINNATI OH 45247',
#   'plaintiff_attorney': 'GREENBERGER/JEFFREY/J',
#   'defendant_name': 'LAKEISHA RODGERS',
#   'defendant_address': '5745 SPRINGDALE RD APT #12 CINCINNATI OH 45247',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03227',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FATH PROPERTIES VS. JOCELYN PARKS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 1),
#   'case_type': 'G2-EVICTION',
#   'amount': 2857,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 8, 9),
#   'plaintiff_name': 'FATH PROPERTIES',
#   'plaintiff_address': 'COMPTON LAKES APTS 255 E FIFTH ST STE 2300CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'JOCELYN PARKS',
#   'defendant_address': '8751 MONSANTO DR CINCINNATI OH 45231',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03226',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FATH PROPERTIES VS. TONIA STARKEY',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 1),
#   'case_type': 'G2-EVICTION',
#   'amount': 1592,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 4, 16),
#   'plaintiff_name': 'FATH PROPERTIES',
#   'plaintiff_address': 'COMPTON LAKE APTS 255 E FIFTH ST STE 2300CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'TONIA STARKEY',
#   'defendant_address': '7822-A COMPTON LAKE DR CINCINNATI OH 45231',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03223',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'MICHAEL RAWLS VS. RICKY BROWN',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 1),
#   'case_type': 'G2-EVICTION',
#   'amount': 10200,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 5, 30),
#   'plaintiff_name': 'MICHAEL RAWLS',
#   'plaintiff_address': 'DBA 6239-6241 LLC 6224 BETTS AVECINCINNATI OH 45224',
#   'plaintiff_attorney': 'BELL SR/WILLIAM/D',
#   'defendant_name': 'RICKY BROWN',
#   'defendant_address': '1609 SUMMIT RD CINCINNATI OH 45237',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03156',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'UPTOWN RENTAL PROPERTIES LLC VS. DIONTE NELSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 1),
#   'case_type': 'G2-EVICTION',
#   'amount': 4021,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 9, 3),
#   'plaintiff_name': 'UPTOWN RENTAL PROPERTIES LLC',
#   'plaintiff_address': '2718 VINE STREET CINCINNATI OH 45219',
#   'plaintiff_attorney': 'BREWER/KEVIN/R',
#   'defendant_name': 'DIONTE NELSON',
#   'defendant_address': 'APT 1 255 MCGREGOR AVECINCINNATI OH 45219',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03072',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'LAFEUILLE APARTMENTS LLC VS. DASHANIA GRAVES',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 31),
#   'case_type': 'G2-EVICTION',
#   'amount': 7235,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2020, 6, 18),
#   'plaintiff_name': 'LAFEUILLE APARTMENTS LLC',
#   'plaintiff_address': '% PLK COMMUNITIES LLC 2682 LAFEUILLE CIRCLE STE 4CINCINNATI OH 45211',
#   'plaintiff_attorney': 'GREENBERGER/JEFFREY/J',
#   'defendant_name': 'DASHANIA GRAVES',
#   'defendant_address': '3348 NIAGARA ST CINCINNATI OH 45251',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV02786',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'PLATINUM PROPERTY MANAGEMENT VS. CRYSTAL V. LAWRENCE',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 28),
#   'case_type': 'G2-EVICTION',
#   'amount': 2400,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 6, 27),
#   'plaintiff_name': 'PLATINUM PROPERTY MGMT',
#   'plaintiff_address': 'P O BOX 37802 CINCINNATI OH 45222',
#   'plaintiff_attorney': 'GILES/BRIAN/T',
#   'defendant_name': 'CRYSTAL V LAWRENCE',
#   'defendant_address': '1609 NIELSON PL CINCINNATI OH 45206',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV02743',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ANGELA MASON VS. KEANE MATHIS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 25),
#   'case_type': 'G2-EVICTION',
#   'amount': 7080,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 4, 9),
#   'plaintiff_name': 'ANGELA MASON',
#   'plaintiff_address': '9056 FONTAINEBLEAU TERRACE CINCINNATI OH 45231',
#   'plaintiff_attorney': None,
#   'defendant_name': 'KEANE MATHIS',
#   'defendant_address': '2932 COSTELLO AVENUE CINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV02645',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'RUSSELL STARK VS. DUNCAN WARREN ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 1, 25),
#   'case_type': 'G2-EVICTION',
#   'amount': 8157,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 5, 2),
#   'plaintiff_name': 'RUSSELL STARK',
#   'plaintiff_address': 'DBA AFFINITY AIR LIMOUSINE SERV 3440 CHURCH STCINCINNATI OH 45244',
#   'plaintiff_attorney': 'SLOVIN/RANDY/T',
#   'defendant_name': 'DUNCAN WARREN',
#   'defendant_address': '4184 CANNON GATE DR CINCINNATI OH 45245',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03655',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'TUJUANA L AKINS VS. TUJUANA W AKINS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 8),
#   'case_type': 'G2-EVICTION',
#   'amount': 37,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 4, 17),
#   'plaintiff_name': 'TUJUANA L AKINS',
#   'plaintiff_address': '10686 TOULON DR CINCINNATI OH 45240',
#   'plaintiff_attorney': None,
#   'defendant_name': 'TUJUANA W AKINS',
#   'defendant_address': '3984 FAWNHILL LANE CINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03534',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'PDPI LLC VS. FRED CRAWFORD',
#   'judge': 'JACKIE GINOCCHIO',
#   'filed_date': datetime.date(2019, 2, 7),
#   'case_type': 'G2-EVICTION',
#   'amount': 3000,
#   'disposition': 'TRANSFERRED OUT',
#   'disposition_date': datetime.date(2020, 2, 10),
#   'plaintiff_name': 'POPI LLC',
#   'plaintiff_address': '2335 PARK AVE CINCINNATI OH 45206',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'FRED CRAWFORD',
#   'defendant_address': '1ST FL 3348 BONAPARTE AVECINCINNATI OH 45207',
#   'defendant_attorney': 'KELLY/ROBERT/G',
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03398',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'NATASHA M CAVANAUGH VS. DAVID BROCK ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 5),
#   'case_type': 'G2-EVICTION',
#   'amount': 3243,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 1, 8),
#   'plaintiff_name': 'NATASHA M CAVANAUGH',
#   'plaintiff_address': '3868 RICHARDSON ROAD INDEPENDENCE KY 41051',
#   'plaintiff_attorney': None,
#   'defendant_name': 'DAVID BROCK',
#   'defendant_address': '5121 KIEFFER RD INDEPENDENCE KY 41051',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03317',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'MARCO GULLEY VS. SHENEVA HOLLOMAN ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 5),
#   'case_type': 'G2-EVICTION',
#   'amount': 2000,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 4, 22),
#   'plaintiff_name': 'MARCO GULLEY',
#   'plaintiff_address': '2916 GLENWAY AVE CINCINNATI OH 45204',
#   'plaintiff_attorney': None,
#   'defendant_name': 'SHENEVA HOLLOMAN',
#   'defendant_address': '1637 MINION CINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV03232',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'MARY HULLER VS. KIM NEWMAN ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 4),
#   'case_type': 'G2-EVICTION',
#   'amount': 3720,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 4, 8),
#   'plaintiff_name': 'MARY HULLER',
#   'plaintiff_address': '5398 SALEM RD CINCINNATI OH 45230',
#   'plaintiff_attorney': None,
#   'defendant_name': 'KIM NEWMAN',
#   'defendant_address': '1027 WOODLAWN AVE CINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV04220',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'NORWOOD INVESTMENT PROPS LLC VS. EVELYN ROBERSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 15),
#   'case_type': 'G2-EVICTION',
#   'amount': 600,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 6, 4),
#   'plaintiff_name': 'NORWOOD INVESTMENT PROPS LLC',
#   'plaintiff_address': 'PO BOX 30277 CINCINNATI OH 45230',
#   'plaintiff_attorney': 'DONNETT/DAVID/D',
#   'defendant_name': 'EVELYN ROBERSON',
#   'defendant_address': '3375 MCHENRY AVE CINCINNATI OH 45225',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV04207',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'MICHAEL WEBER VS. JULIA CONNELLY',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 15),
#   'case_type': 'G2-EVICTION',
#   'amount': 3675,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 5, 23),
#   'plaintiff_name': 'MICHAEL WEBER',
#   'plaintiff_address': '1726 YOUNG ST CINCINNATI OH 45202',
#   'plaintiff_attorney': None,
#   'defendant_name': 'JULIA CONNELLY',
#   'defendant_address': 'APT 16 4401-5 FLORAL AVECINCINNATI OH 45212',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV04153',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. GREATA J FOWLE',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 1051,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 8, 6),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'GREATA J FOWLE',
#   'defendant_address': 'STE 1116 1621 LINN STCINCINNATI OH 45214',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV04149',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. INDIA FINNELL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 485,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 8, 6),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'JOHNSON/DONTE',
#   'defendant_name': 'INDIA A FINNELL',
#   'defendant_address': 'PO COX 32 3 TAYLOR AVENORTH BEND OH 45052',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV04146',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. SHEKILA LEWIS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 2120,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2019, 9, 12),
#   'plaintiff_name': 'CINCINNATI METRO HOUSING AUTH',
#   'plaintiff_address': '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'plaintiff_attorney': 'HEIS/FOREST/S',
#   'defendant_name': 'SHEKILA D LEWIS',
#   'defendant_address': 'STE 61 4743 ESTE AVECINCINNATI OH 45232',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 28)},
#  {'case_id': '19CV04143',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'CMHA VS. KENNETH HINES',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 2, 14),
#   'case_type': 'G2-EVICTION',
#   'amount': 201,
#   'disposition': 'DEFAULT JUDGMENT',
#   'disposition_date': datetime.date(2020, 8, 6),
# ...
#   'defendant_name': 'MARK HALL JR',
#   'defendant_address': '5111 HAWAIIAN TERRACE #4 CINCINNATI OH 45223',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21183',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'KAAPS 5170 LLC VS. BERNETTA PERKINS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G1-EVICTION',
#   'amount': None,
#   'disposition': 'JUDGMENT FOR PLAINTIFF',
#   'disposition_date': datetime.date(2019, 9, 18),
#   'plaintiff_name': 'KAAPS 5170 LLC',
#   'plaintiff_address': 'DBA AIRY WOODS APTS 5135 HAWAIIAN TERRACE #4CINCINNATI OH 45223',
#   'plaintiff_attorney': 'MODDERMAN/GEOFFREY/ALAN',
#   'defendant_name': 'BERNETTA PERKINS',
#   'defendant_address': '5107 HAWAIIAN TERRACE #8 CINCINNATI OH 45223',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21181',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ROSARIO APARTMENTS LLC VS. LINDA CANADY',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 650,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ROSARIO APARTMENTS LLC',
#   'plaintiff_address': 'DBA COACHWOOD APARTMENTS 3091 MCHENRY AVE SUITE 4CINCINNATI OH 45211',
#   'plaintiff_attorney': 'MODDERMAN/GEOFFREY/ALAN',
#   'defendant_name': 'LINDA CANADY',
#   'defendant_address': '3097 MCHENRY AVE APT #11 CINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21180',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FIRST KEY HOMES LLC VS. KAREN ANDERSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1175,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 9),
#   'plaintiff_name': 'FIRST KEY HOMES LLC',
#   'plaintiff_address': '810 SYCAMORE STREET STE 211 CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HODGES/J/THOMAS',
#   'defendant_name': 'KAREN ANDERSON',
#   'defendant_address': '5658 BUTTERCUP LANE CINCINNATI OH 45239',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21179',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FIRST KEY HOMES LLC VS. RENDARDO ANDERSON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1170,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 9),
#   'plaintiff_name': 'FIRST KEY HOMES LLC',
#   'plaintiff_address': '810 SYCAMORE STREET STE 211 CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HODGES/J/THOMAS',
#   'defendant_name': 'RENDARDO ANDERSON',
#   'defendant_address': '2841 VEAZEY AVENUE CINCINNATI OH 45238',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21178',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'FIRST KEY HOMES LLC VS. GABRIELLA BALLARD',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1207,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 9),
#   'plaintiff_name': 'FIRST KEY HOMES LLC',
#   'plaintiff_address': '810 SYCAMORE STREET STE 211 CINCINNATI OH 45202',
#   'plaintiff_attorney': 'HODGES/J/THOMAS',
#   'defendant_name': 'GABRIELLA BALLARD',
#   'defendant_address': '1453 SUMME DRIVE CINCINNATI OH 45231',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21137',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'SNS MANAGEMENT LLC VS. ISSA SIENOU ALL UNKNOWN OCCUPANTS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1000,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 20),
#   'plaintiff_name': 'SNS MANAGEMENT LLC',
#   'plaintiff_address': 'PO BOX 31208 CINCINNATI OH 45231',
#   'plaintiff_attorney': 'BEYKE/JOSEPH/L',
#   'defendant_name': 'ISSA SIENOU',
#   'defendant_address': '110 KOEHLER AVENUE APT 3 CINCINNATI OH 45215',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21135',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ZEPHYR C PROPERTIES VS. GREG COOKE AND ANGELA OBRYANT',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 750,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 18),
#   'plaintiff_name': 'ZEPHYR C PROPERTIES',
#   'plaintiff_address': '% JEFFREY S ROUTH 2344 KEMPER LANE SUITE 6100CINCINNATI OH 45206',
#   'plaintiff_attorney': 'ROUTH/JEFFREY/S',
#   'defendant_name': 'GREG COOKE',
#   'defendant_address': '2422 QUATMAN AVE APT 2 CINCINNATI OH 45212',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21134',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'WINTON HOUSE SENIOR APARTMENTS VS. DURELL SENE AND ANY OTHER TENANTS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 260,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 12),
#   'plaintiff_name': 'WINTON HOUSE SENIOR APTS LP',
#   'plaintiff_address': '1150 WAYCROSS ROAD CINCINNATI OH 45240',
#   'plaintiff_attorney': "O'CONNOR/MICHAEL/J",
#   'defendant_name': 'DURELL SENE',
#   'defendant_address': '1156 WAYCROSS ROAD APT A108 CINCINNATI OH 45240',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21099',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ANDREW L SMITH VS. LISA MARIE SMITH',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 730,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ANDREW L SMITH',
#   'plaintiff_address': 'STE 2600 ROLFES HENRY 600 VINE STCINCINNATI OH 45202',
#   'plaintiff_attorney': 'SMITH/ANDREW/L',
#   'defendant_name': 'LISA MARIE SMITH',
#   'defendant_address': 'APT 1 3123 BRACKEN WOOD LNCINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21098',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'PENKLOR MHP LLC VS. SHERYL MCCLELLAND',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1809,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'PENKLOR MHP LLC',
#   'plaintiff_address': 'STE 110 9918 CARVER RDCINCINNATI OH 45242',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'SHERYL MCCLELLAND',
#   'defendant_address': '101 FERNALD DR HARRISON OH 45030',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21097',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'PENKLOR MHP LLC VS. DANNY R THOMAS ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1543,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'PENKLOR MHP LLC',
#   'plaintiff_address': 'STE 110 9918 CARVER RDCINCINNATI OH 45242',
#   'plaintiff_attorney': 'HEYMAN/D/ANDREW',
#   'defendant_name': 'DANNY R THOMAS',
#   'defendant_address': 'LOT #60 8001 HAMILTON AVECINCINNATI OH 45231',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21096',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ME REAL ESTATE VS. PERNELL DIXON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 10,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ME REAL ESTATE',
#   'plaintiff_address': 'STE 232 2300 MONTANA AVECINCINNATI OH 45211',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'PERNELL DIXON',
#   'defendant_address': '3050 MICKEY #6 CINCINNATI OH 45204',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21095',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ME REAL ESTATE VS. TIFFANY WYNN',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 10,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ME REAL ESTATE',
#   'plaintiff_address': 'STE 232 2300 MONTANA AVECINCINNATI OH 45211',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'TIFFANY WYNN',
#   'defendant_address': '3050 MICKEY #37 CINCINNATI OH 45204',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21094',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ME REAL ESTATE VS. TRACY HARRIS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 10,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ME REAL ESTATE',
#   'plaintiff_address': 'STE 232 2300 MONTANA AVECINCINNATI OH 45211',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'TRACY HARRIS',
#   'defendant_address': '3050 MICKEY #25 CINCINNATI OH 45204',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21093',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ME REAL ESTATE VS. SYLVESTER MASON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 10,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ME REAL ESTATE',
#   'plaintiff_address': 'STE 232 2300 MONTANA AVECINCINNATI OH 45211',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'SYLVESTER MASON',
#   'defendant_address': '3050 MICKEY #9C CINCINNATI OH 45204',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21092',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'WM RENTALS LLC VS. LYNN WILLIAMS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1681,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'WM RENTALS LLC',
#   'plaintiff_address': '2938 VERNON PL CINCINNATI OH 45219',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'LYNN WILLIAMS',
#   'defendant_address': 'APT 1 2936 W MCMICKENCINCINNATI OH 45225',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21091',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'DETTINGER LLC VS. ANDRE HIGGINS',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1777,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'DETTINGER LLC',
#   'plaintiff_address': '2938 VERNON PL CINCINNATI OH 45219',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'ANDRE HIGGINS',
#   'defendant_address': 'APT 11 3317 CAMVICCINCINNATI OH 45211',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21090',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': '2346 2348 2350 BEECHMONT LLC VS. SAMANTHA HAGER ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 1193,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': '2346 2348 2350 BEECHMONT LLC',
#   'plaintiff_address': '2938 VERNON PL CINCINNATI OH 45219',
#   'plaintiff_attorney': 'CHATFIELD/MELANCTHON/W',
#   'defendant_name': 'SAMANTHA HAGER',
#   'defendant_address': 'APT 4 2350 BEECHMONT AVECINCINNATI OH 45230',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21089',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'YRR PROPERTIES LLC VS. ETHAN R BARRETT',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 23),
#   'case_type': 'G2-EVICTION',
#   'amount': 5025,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'YRR PROPERTIES LLC',
#   'plaintiff_address': '% NORTH STAR REALTY PO BOX 397LOVELAND OH 45140',
#   'plaintiff_attorney': 'BREWER/KEVIN/R',
#   'defendant_name': 'ETHAN R BARRETT',
#   'defendant_address': 'AKA ETHAN BARRETT 35 GAHL TERRACE APT DCINCINNATI OH 45215',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21088',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'TONY AUCIELLO VS. REGINALD WHEELER ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 22),
#   'case_type': 'G2-EVICTION',
#   'amount': 2380,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2019, 9, 17),
#   'plaintiff_name': 'TONY AUCIELLO',
#   'plaintiff_address': '5968 BRIDGETOWN RD CINCINNATI OH 45248',
#   'plaintiff_attorney': None,
#   'defendant_name': 'REGINALD WHEELER',
#   'defendant_address': '1238 FIRST (1ST)AVE APT 2 CINCINNATI OH 45205',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21087',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'JOHN CODY VS. TASHA UNDERWOOD',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 22),
#   'case_type': 'G2-EVICTION',
#   'amount': 595,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'JOHN CODY',
#   'plaintiff_address': '3757 PAXTON AVENUE CINCINNATI OH 45209',
#   'plaintiff_attorney': None,
#   'defendant_name': 'TASHA UNDERWOOD',
#   'defendant_address': '2612 DUCKCREEK ROAD APT 1 CINCINNATI OH 45212',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21086',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ELLIOTT REAL ESTATE LLC VS. BRANDON FEARS ET AL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 22),
#   'case_type': 'G2-EVICTION',
#   'amount': 1178,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ELLIOTT REAL ESTATE LLC',
#   'plaintiff_address': '5685 CHESTNUT RIDGE CINCINNATI OH 45230',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'BRANDON FEARS',
#   'defendant_address': '2477 PARIS AVE APT 6 CINCINNATI OH 45219',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21085',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'ELLIOTT REAL ESTATE LLC VS. NICOLE JACKSON PRESTON',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 22),
#   'case_type': 'G2-EVICTION',
#   'amount': 890,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'ELLIOTT REAL ESTATE LLC',
#   'plaintiff_address': '5685 CHESTNUT RIDGE CINCINNATI OH 45230',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'NICOLE JACKSON PRESTON',
#   'defendant_address': '538 ROCKDALE AVE APT 4 CINCINNATI OH 45229',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  {'case_id': '19CV21084',
#   'court': 'MUNICIPAL CIVIL',
#   'case_caption': 'QUARRA PROPERTIES LTD VS. STEPHEN BELL',
#   'judge': 'UNAVAILABLE',
#   'filed_date': datetime.date(2019, 8, 22),
#   'case_type': 'G2-EVICTION',
#   'amount': 600,
#   'disposition': 'DISMISSED',
#   'disposition_date': datetime.date(2020, 10, 30),
#   'plaintiff_name': 'QUARRA PROPERTIES LTD',
#   'plaintiff_address': 'PO BOX 8055 CINCINNATI OH 45208',
#   'plaintiff_attorney': 'RICHARDS/STUART/L',
#   'defendant_name': 'STEPHEN BELL',
#   'defendant_address': '2235 KEMPER LN APT 3 CINCINNATI OH 45206',
#   'defendant_attorney': None,
#   'last_updated': datetime.date(2022, 7, 30)},
#  ...]

# %% [markdown]
# 3. Test web-scraping new records and adding them to our db:
# issue 1: chrome browser's version was more recent than chromedriver's. Needed to update.A few more bugs came out of testing. Now it's running successfully.

# %%
db.add_new_records(end_date='07152022')
# Out:
# found 141 records
# found 363 records
# finished scraping. about to inject records into the db
# converted pd into records
# finished commit

# %%
with conn.cursor() as c:
    c.execute('select * from eviction_records order by filed_date DESC limit 3;')
    data = c.fetchall()

data
# Out:
# [('22CV13831',
#   'MUNICIPAL CIVIL',
#   'SANCTUARY HOLDING GROUP LLC VS. JOSH GRATHWOHL',
#   'UNAVAILABLE',
#   datetime.date(2022, 7, 15),
#   'G1-EVICTION',
#   None,
#   'JUDGMENT FOR PLAINTIFF',
#   datetime.date(2022, 8, 17),
#   'SANCTUARY HOLDING GROUP LLC',
#   '%3BLONDES REALTY LLC 5981 HARRISON AVE SUITE #4CINCINNATI OH 45248',
#   'HASSMAN/ROBERT/C/JR',
#   'JOSH GRATHWOHL',
#   '3313 NORTH BEND RD UNIT I CINCINNATI OH 45239',
#   None,
#   datetime.date(2022, 9, 18)),
#  ('22CV13830',
#   'MUNICIPAL CIVIL',
#   '3801 DINA LLC VS. JASMINE HENDERSON',
#   'UNAVAILABLE',
#   datetime.date(2022, 7, 15),
#   'G2-EVICTION',
#   2908,
#   None,
#   None,
#   '3801 DINA LLC',
#   '8221 CORNELL RD STE 410 CINCINNATI OH 45249',
#   'GLENNON/THOMAS',
#   'JASMINE HENDERSON',
#   '3811 DINA AVE APT 9 CINCINNATI OH 45211',
#   None,
#   datetime.date(2022, 9, 18)),
#  ('22CV13829',
#   'MUNICIPAL CIVIL',
#   '3801 DINA LLC VS. SETH Y KUTANDO',
#   'UNAVAILABLE',
#   datetime.date(2022, 7, 15),
#   'G2-EVICTION',
#   1710,
#   'DISMISSED',
#   datetime.date(2022, 8, 8),
#   '3801 DINA LLC',
#   '8221 CORNELL RD STE 410 CINCINNATI OH 45249',
#   'GLENNON/THOMAS',
#   'SETH Y KUTANDO',
#   '3808 DINA AVE APT 11 CINCINNATI OH 45211',
#   None,
#   datetime.date(2022, 9, 18))]

# %% [markdown]
# 4. Testing update of records method. After lenghty debugging, it works:

# %%
db.update_existing_records_disposition(records_per_batch=30, limit=10)
# Out:
#      case_id disposition disposition_date last_updated
# 0  19CV01204        None             None   2022-09-18
# 1  19CV01199        None             None   2022-09-18
# 2  19CV01195        None             None   2022-09-18
# 3  19CV01194        None             None   2022-09-18
# 4  19CV01193        None             None   2022-09-18
# 5  19CV01186        None             None   2022-09-18
# 6  19CV01185        None             None   2022-09-18
# 7  19CV01173        None             None   2022-09-18
# 8  19CV01172        None             None   2022-09-18
# 9  19CV01009        None             None   2022-09-18

# %%
with conn.cursor() as c:
    c.execute(
        """select * from eviction_records where case_id in (
            '19CV01186', '19CV01185', '19CV01173', '19CV01172');""")
    data = c.fetchall()

data
# Out:
# [('19CV01172',
#   'MUNICIPAL CIVIL',
#   'CMHA VS. WALTER ROGERS',
#   'UNAVAILABLE',
#   datetime.date(2019, 1, 14),
#   'G2-EVICTION',
#   699,
#   None,
#   None,
#   'CINCINNATI METRO HOUSING AUTH',
#   '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'JOHNSON/DONTE',
#   'WALTER E ROGERS',
#   '330 FOREST AVE SUITE 1303 CINCINNATI OH 452292462',
#   None,
#   datetime.date(2022, 9, 18)),
#  ('19CV01173',
#   'MUNICIPAL CIVIL',
#   'CMHA VS. BONNIE ROGESKI',
#   'UNAVAILABLE',
#   datetime.date(2019, 1, 14),
#   'G2-EVICTION',
#   607,
#   None,
#   None,
#   'CINCINNATI METRO HOUSING AUTH',
#   '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'JOHNSON/DONTE',
#   'BONNIE E ROGESKI',
#   '1820 RUTLAND AVE SUITE 106 CINCINNATI OH 452071244',
#   None,
#   datetime.date(2022, 9, 18)),
#  ('19CV01185',
#   'MUNICIPAL CIVIL',
#   'CMHA VS. MAKAILA LUCKEY',
#   'UNAVAILABLE',
#   datetime.date(2019, 1, 14),
#   'G2-EVICTION',
#   393,
#   None,
#   None,
#   'CINCINNATI METRO HOUSING AUTH',
#   '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'JOHNSON/DONTE',
#   'MAKAILA A LUCKEY',
#   '835 POPLAR ST SUITE 204 CINCINNATI OH 452142531',
#   None,
#   datetime.date(2022, 9, 18)),
#  ('19CV01186',
#   'MUNICIPAL CIVIL',
#   'CMHA VS. SHAILA KNIGHT',
#   'UNAVAILABLE',
#   datetime.date(2019, 1, 14),
#   'G2-EVICTION',
#   195,
#   None,
#   None,
#   'CINCINNATI METRO HOUSING AUTH',
#   '1627 WESTERN AVENUE CINCINNATI OH 45214',
#   'JOHNSON/DONTE',
#   'SHAILA E KNIGHT',
#   '835 POPLAR ST SUITE 205 CINCINNATI OH 452142531',
#   None,
#   datetime.date(2022, 9, 18))]
